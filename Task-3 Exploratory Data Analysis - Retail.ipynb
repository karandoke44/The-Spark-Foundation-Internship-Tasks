# %% [markdown]
# # Exploratory Data Analysis - Retail  (Beginner Level)
#
# #### Tableau Dashboard Link: https://public.tableau.com/app/profile/divyam.singh/viz/SuperStoreSales_16473449305440/Dashboard1
# #### Youtube Video Link: https://youtu.be/49EHjsgTXLU

# %% [markdown]
# ### Author : Divyam Singh

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('SampleSuperstore.csv')  #loading dataset

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.isnull().sum()     # for checking null values  ()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# #### No null values are there

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.drop_duplicates(subset=None,keep='first',inplace=True)

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
plt.figure(figsize=(8,8))
corr = df.corr()
sns.heatmap(corr,annot=True,cmap='Greens')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### We can observe that the 'Sales' is highly correlated with Profit , So in order to increase the profit, the sales must be increased
# ### Discount has Negative correlation with Profit

# %%
df['Ship Mode'].value_counts()
# Out:
# Standard Class    5955
# Second Class      1943
# First Class       1537
# Same Day           542
# Name: Ship Mode, dtype: int64

# %%
sns.countplot(x=df['Ship Mode'])
# Out:
# <AxesSubplot:xlabel='Ship Mode', ylabel='count'>

# %% [markdown]
# ### We can observe that the most common ship mode is 'Standard Class' and the least common ship mode is 'Same Day' . <br><br> The standard class may have been less expensive. We can also get people into buying into the Same day options by offering discounts and coupens.

# %%
sns.countplot(x = 'Segment',data = df, )
# Out:
# <AxesSubplot:xlabel='Segment', ylabel='count'>

# %% [markdown]
# ### The Most common segment is Consumer and the least common segment is Home Office

# %%
df['Sub-Category'].value_counts()
# Out:
# Binders        1522
# Paper          1359
# Furnishings     956
# Phones          889
# Storage         846
# Art             795
# Accessories     775
# Chairs          615
# Appliances      466
# Labels          363
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %% [markdown]
# ### We should focus on the quality of products that are bought less.

# %%
plt.figure(figsize=(15,12))
df['Sub-Category'].value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ### binders, Paper, Furnishings and phones sub categories are larger than the sub categories like tables, envelops, supplies etc.

# %%
df['State'].value_counts()
# Out:
# California              1996
# New York                1127
# Texas                    983
# Pennsylvania             586
# Washington               502
# Illinois                 491
# Ohio                     468
# Florida                  383
# Michigan                 254
# North Carolina           249
# Virginia                 224
# Arizona                  224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   123
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Missouri                  66
# Oklahoma                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Mississippi               53
# Utah                      53
# ...

# %% [markdown]
# ### Our company can offer special kind of products for specific states to increase the sales from these states

# %%
plt.figure(figsize=(15,12))
sns.countplot(x='State',data=df,palette='rocket_r',order=df['State'].value_counts().index)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Most of the rows contain California ie highest buyers are from California

# %%
plt.figure(figsize=(10,10))
explode = [0.1,.1,.1,.1]
df['Region'].value_counts().plot.pie(autopct = '%1.1f%%', explode = explode)
plt.show()

# %% [markdown]
# ### The least buyers are from South in the dataframe

# %%
ps = df.groupby('State')[['Sales','Profit']].sum().sort_values(by='Sales',ascending=False)
ps[:].plot.bar(color=['blue','orange'],figsize=(15,8))
plt.title('Profit/loss vs Sales across states')
plt.xlabel('States')
plt.ylabel('Profit/loss & Sales')
plt.show()

# %%
p = df.groupby('Sub-Category')[['Sales','Profit']].sum().sort_values(by='Sales',ascending=False)

# %% [markdown]
# ### The most Profit comes from California and New York , The most Loss comes from Texas, Pennsylvania and Ohio

# %%
df.groupby('Category')[['Profit','Sales']].sum().plot.bar(color=['yellow','purple'],alpha=0.9,figsize=(12,9))
plt.ylabel('Profit/Loss and sales')
plt.show()

# %% [markdown]
# ### The profit of Furniture is very less as compared to the Sales

# %%
p
# Out:
#                     Sales      Profit
# Sub-Category
# Phones        330007.0540  44515.7306
# Chairs        327777.7610  26567.1278
# Storage       223843.6080  21278.8264
# Tables        206965.5320 -17725.4811
# Binders       203409.1690  30228.0003
# Machines      189238.6310   3384.7569
# Accessories   167380.3180  41936.6357
# Copiers       149528.0300  55617.8249
# Bookcases     114879.9963  -3472.5560
# Appliances    107532.1610  18138.0054
# Furnishings    91683.0240  13052.7230
# Paper          78224.1420  33944.2395
# Supplies       46673.5380  -1189.0995
# Art            27107.0320   6524.6118
# Envelopes      16476.4020   6964.1767
# Labels         12444.9120   5526.3820
# Fasteners       3024.2800    949.5182

# %%
p[:].plot.bar(color=['blue','Green'],figsize=(15,8))
plt.title('Profit/loss & Sales across states')
plt.xlabel('Sub-Category')
plt.ylabel('Profit/loss & Sales')
plt.show()

# %% [markdown]
# ### Phones sub category is having the highest sales but the highest profit is from the Copiers and Tables is at a huge loss. The Tables sub category should be targeted through advertising, should be made less costly

# %%
plt.figure(figsize = (5,5))
textprops = {"fontsize":10}
plt.title('Category')
plt.pie(df['Category'].value_counts(), labels=df['Category'].value_counts().index,autopct='%1.1f%%',textprops = textprops)
plt.show()

# %%
plt.figure(figsize=(8,7))
sns.lineplot(df['Discount'], df['Profit'], data=df)
# Out:
# C:\Users\Divyam Singh\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Discount', ylabel='Profit'>

# %% [markdown]
# ### No correlation of Discount with Profit

# %%
df.plot(kind = "scatter",figsize = (13,8), x = "Sales", y= "Profit", c = "Discount", s = 20,fontsize = 16, colormap = "viridis")
plt.ylabel('Total Profits',fontsize = 16)
plt.title("Interdependency of Sales,Profits and Discounts",fontsize = 16)

plt.show()

# %% [markdown]
# ### The Profit increases with the Sales but the Profit is decreasing with the increasing discount

# %% [markdown]
# # Conlcusion: <br><br>
# ## 1. The Sales of Tables should be minimized as they are going in loss.
# ## 2. Advertising and Special Discounts for states like West Virnginia and South Dakota can be implemented to increase the sales in these states.
# ## 3. The sales are highly correlated with Profit , so Sales must be increased.
# ## 4. The sales of furniture are giving less profit , so we should limit them.
# ## 5. Profit and sales are maximum in west region and minimum in south region.
